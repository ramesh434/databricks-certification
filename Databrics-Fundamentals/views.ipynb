# %%
# %sql


use catalog practice;
show schemas;

CREATE TABLE IF NOT EXISTS smartphones
(id INT, name STRING, brand STRING, year INT);

INSERT INTO smartphones
VALUES (1, 'iPhone 14', 'Apple', 2022),
      (2, 'iPhone 13', 'Apple', 2021),
      (3, 'iPhone 6', 'Apple', 2014),
      (4, 'iPad Air', 'Apple', 2013),
      (5, 'Galaxy S22', 'Samsung', 2022),
      (6, 'Galaxy Z Fold', 'Samsung', 2022),
      (7, 'Galaxy S9', 'Samsung', 2016),
      (8, '12 Pro', 'Xiaomi', 2022),
      (9, 'Redmi 11T Pro', 'Xiaomi', 2022),
      (10, 'Redmi Note 11', 'Xiaomi', 2021)

# %%
# %sql
--- create standard view 
create view if not exists smartphones_view as select * from smartphones where year> 2022;

# %%
# %sql
select count(* ) from smartphones;

# %% [markdown]
# Create Temp View

# %%
# %sql
create TEMP view  smarphones_view_temp as select * from smartphones where year> 2022;
    
select * from smarphones_view_temp;

# %%
# %sql
show tables;

# %% [markdown]
# Create Global Temp

# %%
# %sql
use catalog practice;
create global temp view  smartphones_global_view_temp as select * from smartphones where year> 2022;

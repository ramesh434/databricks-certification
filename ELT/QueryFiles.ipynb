# %% [markdown]
# ![image_1777479014537.png](./image_1777479014537.png "image_1777479014537.png")

# %%
file = dbutils.fs.ls("dbfs:/databricks-datasets/flights/departuredelays.csv")
display(file)

# %%
# %sql
SELECT * FROM csv.`dbfs:/databricks-datasets/flights/departuredelays.csv`

# %%
# %sql
use catalog practice;
CREATE TABLE default.flights_csv
  (date DATE, delay INT, distance INT, origin STRING, destination STRING)
USING CSV
OPTIONS (
  header = "true",
  delimiter = ","
)
LOCATION "dbfs:/databricks-datasets/flights/departuredelays.csv"
